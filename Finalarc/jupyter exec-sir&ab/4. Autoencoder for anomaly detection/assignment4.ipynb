# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from tensorflow.keras.optimizers import Adam  #Adam optimizer is a smart method that automatically adjusts the learning speed for each parameter, helping the model learn faster and better.
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras import Model, Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import MeanSquaredLogarithmicError

PATH_TO_DATA = 'http://storage.googleapis.com/download.tensorflow.org/data/ecg.csv'
data = pd.read_csv(PATH_TO_DATA, header=None)
data.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.112522 -2.827204 -3.773897 -4.349751 -4.376041 -3.474986 -2.181408
# 1 -1.100878 -3.996840 -4.285843 -4.506579 -4.022377 -3.234368 -1.566126
# 2 -0.567088 -2.593450 -3.874230 -4.584095 -4.187449 -3.151462 -1.742940
# 3  0.490473 -1.914407 -3.616364 -4.318823 -4.268016 -3.881110 -2.993280
# 4  0.800232 -0.874252 -2.384761 -3.973292 -4.338224 -3.802422 -2.534510
#
#         7         8         9    ...       131       132       133       134  \
# 0 -1.818286 -1.250522 -0.477492  ...  0.792168  0.933541  0.796958  0.578621
# 1 -0.992258 -0.754680  0.042321  ...  0.538356  0.656881  0.787490  0.724046
# 2 -1.490659 -1.183580 -0.394229  ...  0.886073  0.531452  0.311377 -0.021919
# 3 -1.671131 -1.333884 -0.965629  ...  0.350816  0.499111  0.600345  0.842069
# 4 -1.783423 -1.594450 -0.753199  ...  1.148884  0.958434  1.059025  1.371682
#
#         135       136       137       138       139  140
# 0  0.257740  0.228077  0.123431  0.925286  0.193137  1.0
# 1  0.555784  0.476333  0.773820  1.119621 -1.436250  1.0
# 2 -0.713683 -0.532197  0.321097  0.904227 -0.421797  1.0
# 3  0.952074  0.990133  1.086798  1.403011 -0.383564  1.0
# 4  1.277392  0.960304  0.971020  1.614392  1.421456  1.0
#
# [5 rows x 141 columns]

# %%
# !pip install numpy matplotlib scikit-learn
# Out:
# Requirement already satisfied: numpy in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (2.2.6)
# Requirement already satisfied: matplotlib in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (3.10.7)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp310-cp310-win_amd64.whl (8.9 MB)
#      ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#      - -------------------------------------- 0.3/8.9 MB 6.5 MB/s eta 0:00:02
#      -- ------------------------------------- 0.7/8.9 MB 6.9 MB/s eta 0:00:02
#      --- ------------------------------------ 0.7/8.9 MB 5.0 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.0/8.9 MB 5.3 MB/s eta 0:00:02
#      ----- ---------------------------------- 1.2/8.9 MB 5.3 MB/s eta 0:00:02
#      ------ --------------------------------- 1.3/8.9 MB 5.0 MB/s eta 0:00:02
#      ------- -------------------------------- 1.6/8.9 MB 4.9 MB/s eta 0:00:02
#      ------- -------------------------------- 1.8/8.9 MB 4.7 MB/s eta 0:00:02
9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------- ----- 7.7/8.9 MB 4.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 8.0/8.9 MB 3.9 MB/s eta 0:00:01
#      ------------------------------------ --- 8.1/8.9 MB 3.9 MB/s eta 0:00:01
#      ------------------------------------- -- 8.3/8.9 MB 3.9 MB/s eta 0:00:01
#      -------------------------------------- - 8.5/8.9 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------  8.7/8.9 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------  8.8/8.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  8.8/8.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  8.8/8.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  8.9/8.9 MB 3.7 MB/s eta 0:00:01
#      ---------------------------------------- 8.9/8.9 MB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=3 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from scikit-learn) (1.15.3)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#      ---------------------------------------- 0.0/308.4 kB ? eta -:--:--
#      ------------ ------------------------- 102.4/308.4 kB 2.9 MB/s eta 0:00:01
#      ------------------------------------ - 297.0/308.4 kB 3.7 MB/s eta 0:00:01
#      -------------------------------------- 308.4/308.4 kB 3.2 MB/s eta 0:00:00
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: six>=1.5 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.5.2 scikit-learn-1.7.2 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data.shape
# Out:
# (4998, 141)

# %%
features = data.drop(140, axis=1)
target = data[140]
x_train, x_test, y_train, y_test = train_test_split(
    features, target, test_size=0.2, stratify=target
)
train_index = y_train[y_train == 1].index
train_data = x_train.loc[train_index]

# %%
min_max_scaler = MinMaxScaler(feature_range=(0, 1))
x_train_scaled = min_max_scaler.fit_transform(train_data.copy())   # learn (i.e. if values=(10,20,30) min=10 and max=30) and scale ( converts values in 0 to 1 format)
x_test_scaled = min_max_scaler.transform(x_test.copy())

# %%
class AutoEncoder(Model):
  def __init__(self, output_units, ldim=8):
    super().__init__()
    self.encoder = Sequential([
      Dense(64, activation='relu'),
      Dropout(0.1),
      Dense(32, activation='relu'),
      Dropout(0.1),
      Dense(16, activation='relu'),
      Dropout(0.1),
      Dense(ldim, activation='relu')   # The number of features in the hidden/latent space.
    ])
    self.decoder = Sequential([
      Dense(16, activation='relu'),
      Dropout(0.1),
      Dense(32, activation='relu'),
      Dropout(0.1),
      Dense(64, activation='relu'),
      Dropout(0.1),
      Dense(output_units, activation='sigmoid')
    ])

  def call(self, inputs):
    encoded = self.encoder(inputs)
    decoded = self.decoder(encoded)
    return decoded

# %%
model = AutoEncoder(output_units=x_train_scaled.shape[1])
model.compile(loss='msle', metrics=['mse'], optimizer='adam')
epochs = 20

history = model.fit(
    x_train_scaled,
    x_train_scaled,
    epochs=epochs,
    batch_size=512,
    validation_data=(x_test_scaled, x_test_scaled)
)
# Out:
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 0.0106 - mse: 0.0238 - val_loss: 0.0132 - val_mse: 0.0306
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0101 - mse: 0.0227 - val_loss: 0.0130 - val_mse: 0.0302
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0091 - mse: 0.0203 - val_loss: 0.0126 - val_mse: 0.0294
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0078 - mse: 0.0174 - val_loss: 0.0121 - val_mse: 0.0280
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0066 - mse: 0.0146 - val_loss: 0.0113 - val_mse: 0.0262
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0055 - mse: 0.0123 - val_loss: 0.0106 - val_mse: 0.0247
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0048 - mse: 0.0108 - val_loss: 0.0102 - val_mse: 0.0238
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0044 - mse: 0.0099 - val_loss: 0.0099 - val_mse: 0.0232
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0042 - mse: 0.0095 - val_loss: 0.0098 - val_mse: 0.0228
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0041 - mse: 0.0092 - val_loss: 0.0097 - val_mse: 0.0226
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0040 - mse: 0.0090 - val_loss: 0.0096 - val_mse: 0.0224
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - mse: 0.0088 - val_loss: 0.0095 - val_mse: 0.0222
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0038 - mse: 0.0086 - val_loss: 0.0094 - val_mse: 0.0221
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - mse: 0.0083 - val_loss: 0.0093 - val_mse: 0.0219
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0036 - mse: 0.0081 - val_loss: 0.0093 - val_mse: 0.0217
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0035 - mse: 0.0078 - val_loss: 0.0092 - val_mse: 0.0214
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0034 - mse: 0.0076 - val_loss: 0.0091 - val_mse: 0.0212
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0033 - mse: 0.0073 - val_loss: 0.0090 - val_mse: 0.0210
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0032 - mse: 0.0071 - val_loss: 0.0089 - val_mse: 0.0207
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0031 - mse: 0.0070 - val_loss: 0.0088 - val_mse: 0.0205

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('MSLE Loss')
plt.legend(['loss', 'val_loss'])
plt.show()

# %%
def find_threshold(model, x_train_scaled):
  reconstructions = model.predict(x_train_scaled)
  reconstruction_errors = tf.keras.losses.msle(reconstructions, x_train_scaled)
  threshold = np.mean(reconstruction_errors.numpy()) \
   + np.std(reconstruction_errors.numpy())
  return threshold

def get_predictions(model, x_test_scaled, threshold):
  predictions = model.predict(x_test_scaled)
  errors = tf.keras.losses.msle(predictions, x_test_scaled)
  anomaly_mask = pd.Series(errors) > threshold
  preds = anomaly_mask.map(lambda x: 0.0 if x == True else 1.0)
  return preds

threshold = find_threshold(model, x_train_scaled)
print(f"Threshold: {threshold}")
# Out:
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Threshold: 0.0071806046503098304

# %%
predictions = get_predictions(model, x_test_scaled, threshold)
accuracy_score(predictions, y_test)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 0.952
