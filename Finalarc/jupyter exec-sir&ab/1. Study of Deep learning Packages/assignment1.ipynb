# %%
import numpy as np

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.20.0-cp310-cp310-win_amd64.whl (331.7 MB)
# Requirement already satisfied: setuptools in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (2.2.6)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (6.33.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: packaging in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (1.6.3)
# Collecting keras>=3.10.0
#   Using cached keras-3.12.0-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: six>=1.12.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: namex in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: rich in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: optree in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Installing collected packages: keras, tensorflow
# Successfully installed keras-3.12.0 tensorflow-2.20.0
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from keras import datasets      
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
# !pip install Theano
# Out:
# Collecting Theano
#   Using cached Theano-1.0.5-py3-none-any.whl
# Requirement already satisfied: six>=1.9.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from Theano) (1.17.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from Theano) (2.2.6)
# Requirement already satisfied: scipy>=0.14 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from Theano) (1.15.3)
# Installing collected packages: Theano
# Successfully installed Theano-1.0.5
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu115
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu115
# Collecting torch
#   Using cached torch-2.9.1-cp310-cp310-win_amd64.whl (111.0 MB)
# Collecting torchvision
#   Using cached torchvision-0.24.1-cp310-cp310-win_amd64.whl (3.7 MB)
# Collecting torchaudio
#   Downloading torchaudio-2.9.1-cp310-cp310-win_amd64.whl (663 kB)
#      ---------------------------------------- 0.0/663.9 kB ? eta -:--:--
#      ------------------------ ------------- 430.1/663.9 kB 8.9 MB/s eta 0:00:01
#      -------------------------------------- 663.9/663.9 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: filelock in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: jinja2 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: numpy in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\onkar shirke\appdata\roaming\python\lib\site-packages (from jinja2->torch) (3.0.3)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-2.9.1 torchaudio-2.9.1 torchvision-0.24.1
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
import torch.nn as nn

# %%
print(torch.__version__)
# Out:
# 2.9.1+cpu

# %%
torch.cuda.is_available()
# Out:
# False
